# %%
# %sql
-- "Revisión de DRIVERS con licencia NULL
SELECT *  FROM ecomotive.gold.dim_drivers
WHERE license_ref IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- "Limpieza" accidental: Borrar a quien no tenga licencia registrada
DELETE FROM ecomotive.gold.dim_drivers
WHERE license_ref IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>10</td></tr></tbody></table></div>

# %%
# %sql
-- VERIFICACIÓN DEL DESASTRE
SELECT *  FROM ecomotive.gold.dim_drivers
WHERE license_ref IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>driver_id</th><th>driver_name</th><th>license_ref</th><th>hourly_wage</th><th>certifications</th><th>hire_date</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE HISTORY ecomotive.gold.dim_drivers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- Consultamos el pasado (Versión 1) sin tocar el presente
SELECT * FROM ecomotive.gold.dim_drivers VERSION AS OF 2
WHERE license_ref IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- Deshacemos el borrado volviendo a la versión 1
RESTORE TABLE ecomotive.gold.dim_drivers TO VERSION AS OF 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_size_after_restore</th><th>num_of_files_after_restore</th><th>num_removed_files</th><th>num_restored_files</th><th>removed_files_size</th><th>restored_files_size</th></tr></thead><tbody><tr><td>5183</td><td>1</td><td>1</td><td>1</td><td>5183</td><td>5183</td></tr></tbody></table></div>

# %%
# %sql
-- "Revisión de DRIVERS con licencia NULL
SELECT *  FROM ecomotive.gold.dim_drivers
WHERE license_ref IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
