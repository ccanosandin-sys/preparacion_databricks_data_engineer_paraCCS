# %%
# %sql

SELECT usage_date, sku_name, usage_quantity
FROM system.billing.usage
LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>usage_date</th><th>sku_name</th><th>usage_quantity</th></tr></thead><tbody><tr><td>2025-10-20</td><td>PREMIUM_DATABRICKS_STORAGE_US_EAST_OHIO</td><td>0.000139200000000000</td></tr><tr><td>2025-10-20</td><td>PREMIUM_DATABRICKS_STORAGE_US_EAST_OHIO</td><td>0.002391400000000000</td></tr><tr><td>2025-10-20</td><td>PREMIUM_DATABRICKS_STORAGE_US_EAST_OHIO</td><td>0.000001107819684564</td></tr><tr><td>2025-10-20</td><td>PREMIUM_DATABRICKS_STORAGE_US_EAST_OHIO</td><td>0.000103896835895434</td></tr><tr><td>2025-10-20</td><td>PREMIUM_DATABRICKS_STORAGE_US_EAST_OHIO</td><td>0.002391400000000000</td></tr></tbody></table></div>

# %%
# %sql

SELECT event_time, user_identity, action_name
FROM system.access.audit
LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_time</th><th>user_identity</th><th>action_name</th></tr></thead><tbody><tr><td>2026-01-07T00:50:39.934Z</td><td>List(System-User, null)</td><td>getPipeline</td></tr><tr><td>2026-01-07T00:50:39.904Z</td><td>List(System-User, null)</td><td>getTable</td></tr><tr><td>2026-01-07T00:50:39.853Z</td><td>List(System-User, null)</td><td>getPipeline</td></tr><tr><td>2026-01-07T00:55:38.507Z</td><td>List(System-User, null)</td><td>getPipeline</td></tr><tr><td>2026-01-07T00:55:38.484Z</td><td>List(System-User, null)</td><td>getTable</td></tr></tbody></table></div>

# %%
# %sql

SELECT executed_by, statement_text, total_duration_ms, produced_rows
FROM system.query.history
LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>executed_by</th><th>statement_text</th><th>total_duration_ms</th><th>produced_rows</th></tr></thead><tbody><tr><td>pablo.cumbreraconde@gmail.com</td><td>-- Asegúrate de tener permisos para crear catálogos
# CREATE CATALOG IF NOT EXISTS my_catalog</td><td>477</td><td>0</td></tr><tr><td>pablo.cumbreraconde@gmail.com</td><td>-- Crear un esquema de ejemplo
# CREATE SCHEMA IF NOT EXISTS governance_demo</td><td>1253</td><td>0</td></tr><tr><td>pablo.cumbreraconde@gmail.com</td><td>-- Asegúrate de tener permisos para crear catálogos
# CREATE CATALOG IF NOT EXISTS my_catalog</td><td>16128</td><td>0</td></tr><tr><td>pablo.cumbreraconde@gmail.com</td><td>USE CATALOG my_catalog</td><td>450</td><td>0</td></tr><tr><td>pablo.cumbreraconde@gmail.com</td><td>SELECT * FROM empleados</td><td>2679</td><td>4</td></tr></tbody></table></div>
